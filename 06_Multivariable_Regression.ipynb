# %%
input_file = 'data/data_multivar_regr.txt'

# %%
with open(input_file) as f:
    print(f.readline())
# Out:
# 2.06,3.48,7.21,15.69

# %%
import numpy as np
data = np.loadtxt(input_file,delimiter = ',')

# %%
X,y = data[:,:-1],data[:,-1]

# %%
X.shape
# Out:
# (700, 3)

# %%
len(y)
# Out:
# 700

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = model.predict(X)

# %%
plt.plot(range(len(y)),pow((y_pred-y),2),'.')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X,y,'.')
# Out:
# [<matplotlib.lines.Line2D at 0x2aec7eb2ba8>,
#  <matplotlib.lines.Line2D at 0x2aec7eb2e48>,
#  <matplotlib.lines.Line2D at 0x2aec7eb2f60>]
